# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/HyperNetworks"
# !chmod +x run_static_hypernetwork.sh

# %%
# !bash run_static_hypernetwork.sh train-subset-cifar-svhn

# %%
# !bash run_static_hypernetwork.sh eval-subset-cifar-svhn

# %%
# !python static_hypernetwork.py benchmark --datasets cifar10,svhn --models wrn40_2 --hyper-modes both --results-json runs/benchmark_wrn_cifar_svhn.json

# %%
# !python static_hypernetwork.py train --datasets svhn --models wrn40_2 --hyper-modes baseline

# %%
# !python static_hypernetwork.py eval --datasets svhn --models wrn40_2 --hyper-modes baseline --results-json runs/out.json

# %%
# !bash run_static_hypernetwork.sh eval-subset-cnn
